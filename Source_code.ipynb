# %%
import numpy as np
import pandas as pnd
import time

import matplotlib.pyplot as mp
# %matplotlib inline
import seaborn as sb

from scipy import stats


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

creditcard_data = pnd.read_csv(r'C:\Users\SUKANYA\Documents\credit card\creditcard.csv')

# %%
creditcard_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  \
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539  \
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
creditcard_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473  \
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864  \
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount
# ...

# %%
creditcard_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
creditcard_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
creditcard_data.describe()
# Out:
#                 Time            V1            V2            V3            V4
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
creditcard_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# 0--> Normal Transactions
# 1--> Fraudulent Transaction

# %%
legit = creditcard_data[creditcard_data.Class == 0]
fraud = creditcard_data[creditcard_data.Class == 1]
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#compare the values between both transaction
creditcard_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453  \
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235  \
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131  \
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
print((creditcard_data.groupby('Class')['Class'].count()/creditcard_data['Class'].count())*100)
((creditcard_data.groupby('Class')['Class'].count()/creditcard_data['Class'].count())*100).plot.pie()
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: Class, dtype: float64
# <Axes: ylabel='Class'>

# %%
c=creditcard_data['Class'].value_counts()
normal_p=c[0]/creditcard_data['Class'].count()*100
fraud_p=c[1]/creditcard_data['Class'].count()*100
print(normal_p)
print(fraud_p)
# Out:
# 99.82725143693798
# 0.1727485630620034

# %%
co_relation=creditcard_data.corr()
co_relation
# Out:
#             Time            V1            V2            V3            V4
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01  \
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
mp.figure(figsize=(24,18))
sb.heatmap(co_relation, cmap="coolwarm", annot=True)
mp.show()

# %%
# Splitting dataset into x and y
x = creditcard_data.drop(columns='Class', axis=1)
y = creditcard_data['Class']

# %%
x.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  \
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928  \
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
cols=list(x.columns.values)

normal_record=creditcard_data.Class==0
fraud_record=creditcard_data.Class==1

mp.figure(figsize=(20,60))
for n, col in enumerate(cols):
    mp.subplot(10, 3,n+1)
    sb.histplot(x[col][normal_record], color='purple')
    sb.histplot(x[col][fraud_record], color='yellow')
    mp.title(col, fontsize=16)
mp.show()

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pnd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6
# 27085    34380.0 -0.939481 -0.448025  0.130687  1.245398  1.139785  0.639527  \
# 52392    45422.0 -0.520879  0.329109  1.637914 -0.852327  0.130240  0.437397
# 82244    59320.0 -6.833903  6.502395 -2.270450 -1.187380 -0.154541 -0.981347
# 164414  116700.0 -0.298590  0.229984  0.724188 -0.580750  0.841187  2.183039
# 121999   76397.0 -0.779417  1.064233  0.838019 -0.271958 -0.029792 -0.201436
#
#               V7        V8        V9  ...       V21       V22       V23
# 27085   1.484853 -0.223343 -0.401027  ...  0.199456  0.462378  0.487485  \
# 52392   0.041845  0.129029  0.301546  ...  0.092295  0.549823 -0.180555
# 82244   1.949566 -1.116488  6.801603  ... -1.258550  0.301870  0.124943
# 164414 -0.246621  0.801479  0.172125  ...  0.149240  0.462023  0.106444
# 121999  0.129549  0.639463 -0.560064  ... -0.196438 -0.761535 -0.051974
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494  \
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419  \
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
#uniform distribution is done by new_dataset
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5
# Class
# 0      92369.355691 -0.038678  0.117828  0.075125 -0.058399  0.059036  \
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21
# Class                                          ...
# 0      0.019597  0.055824 -0.018165  0.025478  ...  0.045944 -0.026747  \
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28
# Class
# 0      0.019609 -0.031559 -0.034976 -0.000197 -0.022979 -0.004638 -0.010279  \
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       85.680366
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features and targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6
# 27085    34380.0 -0.939481 -0.448025  0.130687  1.245398  1.139785  0.639527  \
# 52392    45422.0 -0.520879  0.329109  1.637914 -0.852327  0.130240  0.437397
# 82244    59320.0 -6.833903  6.502395 -2.270450 -1.187380 -0.154541 -0.981347
# 164414  116700.0 -0.298590  0.229984  0.724188 -0.580750  0.841187  2.183039
# 121999   76397.0 -0.779417  1.064233  0.838019 -0.271958 -0.029792 -0.201436
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 27085     0
# 52392     0
# 82244     0
# 164414    0
# 121999    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
# Split data into test data and train data :
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
print(Y.shape, Y_train.shape, Y_test.shape)
# Out:
# (984,) (787,) (197,)

# %%
#Model Training: on Logistic Regression
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
# Model Evaluation: Model accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy*100)
# Out:
# Accuracy on Training data :  94.28208386277002

# %%
# Model Evaluation: Model accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy*100)
# Out:
# Accuracy score on Test Data :  89.34010152284264
